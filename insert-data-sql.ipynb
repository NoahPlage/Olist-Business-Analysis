# %%
import pyodbc
import pandas as pd
# for keeping credentials out of sight
import os
from dotenv import load_dotenv


# create a "sql-keys.env" file under the script working directory
# fill in database connection parameters and access tokens and save
# establish working directory path
# getcwd() returns current working directory
wdir_path = os.getcwd()

sql_path = os.path.join(wdir_path, "sql-keys.env") # absolute path of "sql-keys.env"
# load the credentials into os environment 
load_dotenv(sql_path)
#check if credentials loaded successfully
os.environ

# getting credentials information from "sql-keys.env"
server = os.getenv("DB_SERVER")
database = os.getenv("DB_NAME")
username = os.getenv("DB_USERNAME")
password = os.getenv("DB_PASSWORD")
driver = os.getenv("DB_DRIVER")

# setup connection engine details
#engine = db.create_engine(f"postgresql://{user}:{password}@{hostname}:{port_no}/{db_name}")  

# Establish the connection
conn = pyodbc.connect('DRIVER=' + driver + ';SERVER=' + server +
                      ';PORT=1433;DATABASE=' + database + ';UID=' + username +
                      ';PWD=' + password)

print(conn)
# Out:
# <pyodbc.Connection object at 0x00000248779271C0>

# %%
cursor = conn.cursor()

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS movies "
               "(movie_id INT IDENTITY(1,1) PRIMARY KEY, "
               "movie_title VARCHAR(255) NOT NULL, "
               "released_year INT, "
               "runtime INT NOT NULL, "
               "genre VARCHAR(255), "
               "rating INT NOT NULL, "
               "director VARCHAR(255), "
               "star1 VARCHAR(255), "
               "star2 VARCHAR(255), "
               "number_of_votes INT, "
               "gross INT)")

# %%
fpath = "movies.CSV"
df = pd.read_csv(fpath, delimiter=";", encoding="utf8")
df.head()
# Out:
#                                                Title  Released_Year  Runtime  \
# 0                                    The Dark Knight           2008  152 min
# 1      The Lord of the Rings: The Return of the King           2003  201 min
# 2                                          Inception           2010  148 min
# 3  The Lord of the Rings: The Fellowship of the Ring           2001  178 min
# 4              The Lord of the Rings: The Two Towers           2002  179 min
#
#                        Genre  Rating           Director              Star1  \
# 0       Action, Crime, Drama      90  Christopher Nolan     Christian Bale
# 1   Action, Adventure, Drama      89      Peter Jackson        Elijah Wood
# 2  Action, Adventure, Sci-Fi      88  Christopher Nolan  Leonardo DiCaprio
# 3   Action, Adventure, Drama      88      Peter Jackson        Elijah Wood
# 4   Action, Adventure, Drama      87      Peter Jackson        Elijah Wood
#
#                   Star2  Number_of_Votes        Gross
# 0          Heath Ledger          2303232  534,858,444
# 1       Viggo Mortensen          1642758  377,845,905
# 2  Joseph Gordon-Levitt          2067042  292,576,195
# 3          Ian McKellen          1661481  315,544,750
# 4          Ian McKellen          1485555  342,551,365

# %%
def convert_runtime(x):
    """
    Convert the string value to int.
    - Remove "min".
    - Convert to int.
    """
    return int(x.split()[0])

# %%
df['Runtime'] = df['Runtime'].apply(convert_runtime)

# %%
df['Genre'] = df['Genre'].apply(lambda x: x.split(', ')[0])

# %%
def convert_gross(x):
    """
    Convert the string value to int.
    - Remove commas.
    - Convert to int.
    """
    return int(x.replace(',', ''))

# %%
df['Gross'] = df['Gross'].apply(convert_gross)

# %%
for index, row in df.iterrows():
    cursor.execute("INSERT INTO movies "
                   "(movie_title, released_year, runtime, "
                   "genre, rating, director, "
                   "star1, star2, number_of_votes, gross) "
                   "VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", 
                   (row['Title'], row['Released_Year'], row['Runtime'], row['Genre'], row['Rating'], 
                   row['Director'], row['Star1'], row['Star2'], row['Number_of_Votes'], row['Gross']))

# %%
conn.commit()

# %%
cursor.execute("SELECT "
    "movie_id, movie_title "
    "FROM movies")
rows = cursor.fetchall()

# %%
for row in rows:
  print(row)
# Out:
# (1, 'The Dark Knight')
# (2, 'The Lord of the Rings: The Return of the King')
# (3, 'Inception')
# (4, 'The Lord of the Rings: The Fellowship of the Ring')
# (5, 'The Lord of the Rings: The Two Towers')
# (6, 'Interstellar')
# (7, 'Joker')
# (8, 'Whiplash')
# (9, 'The Intouchables')
# (10, 'The Prestige')
# (11, 'The Departed')
# (12, 'The Pianist')
# (13, 'Gladiator')
# (14, 'Spider-Man: Into the Spider-Verse')
# (15, 'Avengers: Endgame')
# (16, 'Avengers: Infinity War')
# (17, 'Coco')
# (18, 'Django Unchained')
# (19, 'The Dark Knight Rises')
# (20, '3 Idiots')
# (21, 'Taare Zameen Par')
# (22, 'WALL·E')
# (23, 'The Lives of Others')
# (24, 'Memento')
# (25, '1917')
# (26, 'Amelie')
# (27, 'Snatch')
# (28, 'Requiem for a Dream')
# (29, 'Green Book')
# (30, 'Drishyam')
# (31, 'Queen')
# (32, 'Warrior')
# (33, 'Shutter Island')
# (34, 'Up')
# (35, 'The Wolf of Wall Street')
# (36, 'Chak De! India')
# (37, 'There Will Be Blood')
# (38, "Pan's Labyrinth")
# (39, 'Toy Story 3')
# (40, 'V for Vendetta')
# (41, 'Rang De Basanti')
# (42, 'Black')
# (43, 'Batman Begins')
# (44, 'Swades: We, the People')
# (45, 'Der Untergang')
# (46, 'Hauru no ugoku shiro')
# (47, 'A Beautiful Mind')
# (48, 'Mommy')
# (49, 'Haider')
# (50, 'Logan')
# (51, 'Room')
# (52, 'PK')
# (53, 'OMG: Oh My God!')
# (54, 'The Grand Budapest Hotel')
# (55, 'Gone Girl')
# (56, 'Inside Out')
# (57, 'Barfi!')
# (58, '12 Years a Slave')
# (59, 'Rush')
# (60, 'Ford v Ferrari')
# (61, 'Spotlight')
# (62, 'Song of the Sea')
# (63, 'Prisoners')
# (64, 'Mad Max: Fury Road')
# (65, 'Gran Torino')
# (66, 'Harry Potter and the Deathly Hallows: Part 2')
# (67, 'How to Train Your Dragon')
# (68, 'Into the Wild')
# (69, 'No Country for Old Men')
# (70, 'Lage Raho Munna Bhai')
# (71, 'Million Dollar Baby')
# (72, 'Finding Nemo')
# (73, 'Catch Me If You Can')
# (74, 'Monsters, Inc.')
# (75, 'Lagaan: Once Upon a Time in India')
# (76, 'La La Land')
# (77, 'Lion')
# (78, 'The Martian')
# (79, 'Wonder')
# (80, 'Gully Boy')
# (81, 'Special Chabbis')
# (82, 'Short Term 12')
# (83, 'Serbuan maut 2: Berandal')
# (84, 'Guardians of the Galaxy')
# (85, 'Blade Runner 2049')
# (86, 'Her')
# (87, 'Bohemian Rhapsody')
# (88, 'The Perks of Being a Wallflower')
# (89, "The King's Speech")
# (90, 'The Help')
# (91, 'Deadpool')
# (92, 'Darbareye Elly')
# (93, 'Dev.D')
# (94, 'My Name Is Khan')
# (95, 'Slumdog Millionaire')
# (96, 'Black Swan')
# (97, 'The Avengers')
# (98, 'Persepolis')
# (99, 'The Pursuit of Happyness')
# (100, 'Blood Diamond')
# (101, 'Sin City')
# (102, 'Le scaphandre et le papillon')
# (103, 'Ratatouille')
# (104, 'Casino Royale')
# (105, 'Pirates of the Caribbean: The Curse of the Black Pearl')
# (106, 'Big Fish')
# (107, 'The Incredibles')
# (108, 'Dogville')
# (109, 'Donnie Darko')
# (110, 'Knives Out')
# (111, 'Marriage Story')
# (112, 'Call Me by Your Name')
# (113, 'I, Daniel Blake')
# (114, 'Isle of Dogs')
# (115, 'Hunt for the Wilderpeople')
# (116, 'Captain Fantastic')
# (117, 'Sing Street')
# (118, 'Thor: Ragnarok')
# (119, 'Nightcrawler')
# (120, 'Jojo Rabbit')
# (121, 'Arrival')
# (122, 'Star Wars: Episode VII - The Force Awakens')
# (123, 'Before Midnight')
# (124, 'X-Men: Days of Future Past')
# (125, "Bir Zamanlar Anadolu'da")
# (126, 'Edge of Tomorrow')
# (127, 'Amour')
# (128, 'The Irishman')
# (129, 'Moon')
# (130, 'The Wrestler')
# (131, 'Jab We Met')
# (132, 'Boyhood')
# (133, 'Star Trek')
# (134, 'In Bruges')
# (135, 'Letters from Iwo Jima')
# (136, 'The Fall')
# (137, 'Life of Pi')
# (138, 'Fantastic Mr. Fox')
# (139, 'Iron Man')
# (140, 'Shaun of the Dead')
# (141, 'Mystic River')
# (142, "No Man's Land")
# (143, 'Almost Famous')
# (144, 'Mulholland Dr.')
# (145, 'Forushande')
# (146, 'Hidden Figures')
# (147, 'Paddington 2')
# (148, 'Kubo and the Two Strings')
# (149, 'M.S. Dhoni: The Untold Story')
# (150, 'Manchester by the Sea')
# (151, 'Rogue One')
# (152, 'Captain America: Civil War')
# (153, 'The Hateful Eight')
# (154, 'Little Women')
# (155, 'Loving Vincent')
# (156, 'The Lunchbox')
# (157, 'Vicky Donor')
# (158, 'Big Hero 6')
# (159, 'About Time')
# (160, 'English Vinglish')
# (161, 'Kaze tachinu')
# (162, 'Toy Story 4')
# (163, 'La migliore offerta')
# (164, 'Moonrise Kingdom')
# (165, 'How to Train Your Dragon 2')
# (166, 'The Big Short')
# (167, 'The Girl with the Dragon Tattoo')
# (168, 'Captain Phillips')
# (169, 'The Hobbit: The Desolation of Smaug')
# (170, 'Das weiße Band - Eine deutsche Kindergeschichte')
# (171, 'Män som hatar kvinnor')
# (172, 'The Fighter')
# (173, 'Taken')
# (174, 'The Boy in the Striped Pyjamas')
# (175, 'The Hobbit: An Unexpected Journey')
# (176, 'Atonement')
# (177, 'Drive')
# (178, 'American Gangster')
# (179, 'Avatar')
# (180, 'Mr. Nobody')
# (181, 'Apocalypto')
# (182, 'Little Miss Sunshine')
# (183, 'Hot Fuzz')
# (184, 'The Curious Case of Benjamin Button')
# (185, 'Pride & Prejudice')
# (186, "The World's Fastest Indian")
# (187, 'Serenity')
# (188, 'Walk the Line')
# (189, 'The Notebook')
# (190, 'Diarios de motocicleta')
# (191, 'Lilja 4-ever')
# (192, 'Les triplettes de Belleville')
# (193, 'The Count of Monte Cristo')
# (194, 'Waking Life')
# (195, 'Remember the Titans')
# (196, 'Wo hu cang long')
# (197, 'Shrek')
# (198, "God's Own Country")
# (199, 'Deadpool 2')
# (200, 'Wind River')
# (201, 'Get Out')
# (202, 'Mission: Impossible - Fallout')
# (203, 'En man som heter Ove')
# (204, 'What We Do in the Shadows')
# (205, 'The Theory of Everything')
# (206, 'Kingsman: The Secret Service')
# (207, 'The Fault in Our Stars')
# (208, 'Me and Earl and the Dying Girl')
# (209, 'The Broken Circle Breakdown')
# (210, 'Captain America: The Winter Soldier')
# (211, 'Rockstar')
# (212, 'Nebraska')
# (213, 'Wreck-It Ralph')
# (214, 'Le Petit Prince')
# (215, 'Detachment')
# (216, 'Midnight in Paris')
# (217, 'The Lego Movie')
# (218, 'Star Trek Into Darkness')
# (219, 'Beasts of No Nation')
# (220, 'The Social Network')
# (221, 'X: First Class')
# (222, 'The Hangover')
# (223, 'Skyfall')
# (224, 'Silver Linings Playbook')
# (225, 'Argo')
# (226, '(500) Days of Summer')
# (227, 'Harry Potter and the Deathly Hallows: Part 1')
# (228, 'Gake no ue no Ponyo')
# (229, 'Frost/Nixon')
# (230, 'Changeling')
# (231, 'Flipped')
# (232, 'This Is England')
# (233, 'Ex Machina')
# (234, 'Efter brylluppet')
# (235, 'The Last King of Scotland')
# (236, 'Zodiac')
# (237, 'Lost in Translation')
# (238, 'Harry Potter and the Goblet of Fire')
# (239, 'Man on Fire')
# (240, 'Coraline')
# (241, 'The Last Samurai')
# (242, 'The Magdalene Sisters')
# (243, 'In America')
# (244, 'I Am Sam')
# (245, 'Adaptation.')
# (246, 'Black Hawk Down')
# (247, 'Road to Perdition')
# (248, 'Das Experiment')
# (249, 'Billy Elliot')
# (250, 'Hedwig and the Angry Inch')
# (251, "Ocean's Eleven")
# (252, 'Vampire Hunter D: Bloodlust')
# (253, 'O Brother, Where Art Thou?')
# (254, 'Training Day')
# (255, 'Searching')
# (256, 'Once Upon a Time... in Hollywood')
# (257, 'The Florida Project')
# (258, 'Gifted')
# (259, 'The Peanut Butter Falcon')
# (260, 'Guardians of the Galaxy Vol. 2')
# (261, 'Baby Driver')
# (262, 'Only the Brave')
# (263, 'Bridge of Spies')
# (264, 'Incredibles 2')
# (265, 'Moana')
# (266, 'Hell or High Water')
# (267, 'Philomena')
# (268, 'Dawn of the Planet of the Apes')
# (269, 'A Star Is Born')
# (270, 'Despicable Me')
# (271, '50/50')
# (272, 'Sherlock Holmes')
# (273, 'The Blind Side')
# (274, 'The Visitor')
# (275, 'Seven Pounds')
# (276, 'Eastern Promises')
# (277, 'Stardust')
# (278, 'The Secret of Kells')
# (279, 'Inside Man')
# (280, 'Gone Baby Gone')
# (281, 'La Vie En Rose')
# (282, 'Huo Yuan Jia')
# (283, 'The Illusionist')
# (284, "Dead Man's Shoes")
# (285, 'Harry Potter and the Half-Blood Prince')
# (286, '300')
# (287, 'Match Point')
# (288, 'Watchmen')
# (289, 'Lord of War')
# (290, 'Saw')
# (291, 'Synecdoche, New York')
# (292, 'Mysterious Skin')
# (293, 'The Station Agent')
# (294, 'Finding Neverland')
# (295, '25th Hour')
# (296, 'The Butterfly Effect')
# (297, '28 Days Later...')
# (298, 'The Royal Tenenbaums')
# (299, 'Enemy at the Gates')
# (300, 'Minority Report')
# (301, 'American Psycho')
# C:\Users\Danny Toh\AppData\Local\Temp\ipykernel_15776\3332637178.py:2: DeprecationWarning: PyUnicode_FromUnicode(NULL, size) is deprecated; use PyUnicode_New() instead
#   print(row)
